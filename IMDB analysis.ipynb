# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"E:\career fair\imdb\IMDB_Movies.csv")
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
data.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
data.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          20
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
lis=[]
for i in data.columns:
    k=data[i].value_counts()
    lis.append(k)
#     print("*******************************************")
print(lis)
# Out:
# [Color               4815
#  Black and White     209
# Name: color, dtype: int64, Steven Spielberg    26
# Woody Allen         22
# Clint Eastwood      20
# Martin Scorsese     20
# Ridley Scott        17
#                     ..
# John Crowley         1
# Rob Pritts           1
# David S. Ward        1
# R.J. Cutler          1
# Daniel Hsia          1
# Name: director_name, Length: 2398, dtype: int64, 1.0      43
# 9.0      37
# 5.0      36
# 10.0     35
# 8.0      35
#          ..
# 738.0     1
# 476.0     1
# 775.0     1
# 552.0     1
# 409.0     1
# Name: num_critic_for_reviews, Length: 528, dtype: int64, 90.0     161
# 100.0    141
# 101.0    139
# 98.0     135
# 97.0     131
#         ...
# 236.0      1
# 334.0      1
# 270.0      1
# 227.0      1
# 47.0       1
# Name: duration, Length: 191, dtype: int64, 0.0      907
# 3.0       70
# 6.0       66
# 7.0       64
# 2.0       63
#         ...
# 593.0      1
# 434.0      1
# 482.0      1
# 667.0      1
# 291.0      1
# ...

# %%
D=['color','language','country','title_year','genres','aspect_ratio']
for i in D:
    k=data[i].value_counts()
    print("name of the columns",i)
    print(k)
    print("*******************************************")
# Out:
# name of the columns color
# Color               4815
#  Black and White     209
# Name: color, dtype: int64
# *******************************************
# name of the columns language
# English       4704
# French          73
# Spanish         40
# Hindi           28
# Mandarin        26
# German          19
# Japanese        18
# Cantonese       11
# Russian         11
# Italian         11
# Portuguese       8
# Korean           8
# Arabic           5
# Danish           5
# Hebrew           5
# Swedish          5
# Polish           4
# Norwegian        4
# Persian          4
# Dutch            4
# Thai             3
# Chinese          3
# Icelandic        2
# None             2
# Indonesian       2
# Aboriginal       2
# Romanian         2
# Dari             2
# Zulu             2
# Panjabi          1
# Urdu             1
# Vietnamese       1
# Slovenian        1
# Greek            1
# Dzongkha         1
# Tamil            1
# Telugu           1
# Kannada          1
# ...

# %%
imdb_data=data[['director_name','duration','actor_1_name','actor_2_name','actor_3_name','num_voted_users','gross','genres','movie_title','language','country','budget','title_year','imdb_score','movie_facebook_likes']]

# %%
imdb_data.head()
# Out:
#        director_name  duration     actor_1_name      actor_2_name  \
# 0      James Cameron     178.0      CCH Pounder  Joel David Moore
# 1     Gore Verbinski     169.0      Johnny Depp     Orlando Bloom
# 2         Sam Mendes     148.0  Christoph Waltz      Rory Kinnear
# 3  Christopher Nolan     164.0        Tom Hardy    Christian Bale
# 4        Doug Walker       NaN      Doug Walker        Rob Walker
#
#            actor_3_name  num_voted_users        gross  \
# 0             Wes Studi           886204  760505847.0
# 1        Jack Davenport           471220  309404152.0
# 2      Stephanie Sigman           275868  200074175.0
# 3  Joseph Gordon-Levitt          1144337  448130642.0
# 4                   NaN                8          NaN
#
#                             genres  \
# 0  Action|Adventure|Fantasy|Sci-Fi
# 1         Action|Adventure|Fantasy
# 2        Action|Adventure|Thriller
# 3                  Action|Thriller
# 4                      Documentary
#
# ...

# %%
imdb_data.isnull().sum()
# Out:
# director_name           104
# duration                 15
# actor_1_name              7
# actor_2_name             13
# actor_3_name             23
# num_voted_users           0
# gross                   884
# genres                    0
# movie_title               0
# language                 12
# country                   5
# budget                  492
# title_year              108
# imdb_score                0
# movie_facebook_likes      0
# dtype: int64

# %%
d=imdb_data[imdb_data['director_name'].isnull()]
imdb_data.drop(d.index,inplace=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_16432\3285839029.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_data.drop(d.index,inplace=True)

# %%
imdb_data.isnull().sum()
# Out:
# director_name             0
# duration                 13
# actor_1_name              7
# actor_2_name             11
# actor_3_name             20
# num_voted_users           0
# gross                   783
# genres                    0
# movie_title               0
# language                 11
# country                   3
# budget                  396
# title_year                4
# imdb_score                0
# movie_facebook_likes      0
# dtype: int64

# %%
imdb_data[imdb_data['language'].isnull()]
# Out:
#             director_name  duration             actor_1_name    actor_2_name  \
# 4             Doug Walker       NaN              Doug Walker      Rob Walker
# 279   Christopher Barnard      22.0              Mathew Buck             NaN
# 3086     Christopher Cain     111.0                Jon Gries  Taylor Handley
# 3539         Richard Rich      45.0          Debi Derryberry    Kate Higgins
# 3869           Mel Brooks      87.0               Sid Caesar     Dom DeLuise
# 4110   Michael Landon Jr.      87.0  William Morgan Sheppard      Kevin Gage
# 4409       John Stockwell      90.0             Matthew Ziff      T.J. Storm
# 4630      Jonathan Meyers     111.0           Justin Baldoni      Luke Perry
# 4810        D.W. Griffith     123.0             Lillian Gish       Mae Marsh
# 4885           King Vidor     151.0             John Gilbert    Renée Adorée
# 4958    Harry F. Millarde     110.0             Stephen Carr  Johnnie Walker
#
# ...

# %%
d=imdb_data[imdb_data['language'].isnull()]
k=d['director_name'].unique()
for i in k:
    kd=imdb_data[(imdb_data['director_name']==i)]['language']
    print(kd)
# Out:
# 4    NaN
# Name: language, dtype: object
# 279    NaN
# Name: language, dtype: object
# 2842    English
# 3086        NaN
# Name: language, dtype: object
# 3539    NaN
# Name: language, dtype: object
# 2079    English
# 3041    English
# 3869        NaN
# 4023    English
# 4158    English
# 4168    English
# 4573    English
# Name: language, dtype: object
# 4110        NaN
# 4230    English
# Name: language, dtype: object
# 1015    English
# 1650    English
# 2862    English
# 4409        NaN
# Name: language, dtype: object
# 4630    NaN
# Name: language, dtype: object
# 4810    NaN
# Name: language, dtype: object
# 3596    English
# 3752    English
# 4885        NaN
# Name: language, dtype: object
# 4958    NaN
# Name: language, dtype: object

# %%
imdb_data.loc[imdb_data['language'].isnull(),'language']='English'

# %%
imdb_data['language'].unique()
# Out:
# array(['English', 'Japanese', 'French', 'Mandarin', 'Aboriginal',
#        'Spanish', 'Filipino', 'Hindi', 'Russian', 'Maya', 'Kazakh',
#        'Telugu', 'Cantonese', 'German', 'Aramaic', 'Italian', 'Dutch',
#        'Dari', 'Hebrew', 'Chinese', 'Mongolian', 'Swedish', 'Korean',
#        'Thai', 'Bosnian', 'None', 'Hungarian', 'Portuguese', 'Icelandic',
#        'Danish', 'Arabic', 'Norwegian', 'Czech', 'Kannada', 'Zulu',
#        'Panjabi', 'Polish', 'Tamil', 'Dzongkha', 'Vietnamese',
#        'Indonesian', 'Urdu', 'Romanian', 'Persian', 'Slovenian', 'Greek',
#        'Swahili'], dtype=object)

# %%
imdb_data.isnull().sum()
# Out:
# director_name             0
# duration                 13
# actor_1_name              7
# actor_2_name             11
# actor_3_name             20
# num_voted_users           0
# gross                   783
# genres                    0
# movie_title               0
# language                  0
# country                   3
# budget                  396
# title_year                4
# imdb_score                0
# movie_facebook_likes      0
# dtype: int64

# %%
d=imdb_data[imdb_data['country'].isnull()].head(2)
imdb_data.drop(d.index,inplace=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_16432\3191370105.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_data.drop(d.index,inplace=True)

# %%
imdb_data['country'].unique()
# Out:
# array(['USA', 'UK', 'New Zealand', 'Canada', 'Australia', 'Belgium',
#        'Japan', 'Germany', 'China', 'France', 'New Line', 'Mexico',
#        'Spain', 'Hong Kong', 'Czech Republic', 'India', 'Soviet Union',
#        'South Korea', 'Peru', 'Italy', 'Russia', 'Aruba', 'Denmark',
#        'Libya', 'Ireland', 'South Africa', 'Switzerland', 'Romania',
#        'West Germany', 'Chile', 'Netherlands', 'Hungary', 'Panama',
#        'Greece', 'Sweden', 'Taiwan', 'Official site', 'Cambodia',
#        'Thailand', 'Slovakia', 'Bulgaria', 'Iran', 'Georgia', 'Iceland',
#        'Norway', 'Turkey', 'Nigeria', 'Brazil', 'Finland', 'Bahamas',
#        'Argentina', nan, 'Colombia', 'Poland', 'Israel', 'Egypt',
#        'Kyrgyzstan', 'Indonesia', 'Pakistan', 'Slovenia', 'Afghanistan',
#        'Dominican Republic', 'Cameroon', 'United Arab Emirates', 'Kenya',
#        'Philippines'], dtype=object)

# %%
imdb_data[imdb_data['country'].isnull()]
# Out:
#           director_name  duration  actor_1_name actor_2_name actor_3_name  \
# 4021  Daniel Petrie Jr.      88.0  Chris Brochu   Jeff Fahey  Rita Wilson
#
#       num_voted_users  gross          genres   movie_title language country  \
# 4021              455    NaN  Drama|Thriller  Dawn Patrol   English     NaN
#
#          budget  title_year  imdb_score  movie_facebook_likes
# 4021  3500000.0      2014.0         4.8                   570

# %%
imdb_data.loc[imdb_data['country'].isnull(),'country']='USA'

# %%
imdb_data.shape
# Out:
# (4937, 15)

# %%
d=imdb_data[imdb_data['actor_1_name'].isnull()]
imdb_data.drop(d.index,inplace=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_16432\3356613678.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_data.drop(d.index,inplace=True)

# %%
imdb_data.drop(columns=['actor_2_name','actor_3_name'],inplace=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_16432\2568737565.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_data.drop(columns=['actor_2_name','actor_3_name'],inplace=True)

# %%
imdb_data.isnull().sum()
# Out:
# director_name             0
# duration                 12
# actor_1_name              0
# num_voted_users           0
# gross                   778
# genres                    0
# movie_title               0
# language                  0
# country                   0
# budget                  393
# title_year                2
# imdb_score                0
# movie_facebook_likes      0
# dtype: int64

# %%
d=imdb_data[imdb_data['gross'].isnull()]

# %%
for i,j,k in zip(imdb_data.loc[(imdb_data['gross'].isnull()==True)]['director_name'],imdb_data.loc[(imdb_data['gross'].isnull()==True)]['language'],imdb_data.loc[(imdb_data['gross'].isnull()==True)]['country']):
    if len(imdb_data.loc[(imdb_data['director_name'] == i)&(imdb_data['language'] == j)&(imdb_data['country'] == k)]['gross'].value_counts())!=0:
        mean=imdb_data.loc[(imdb_data['director_name'] == i)&(imdb_data['language'] == j)&(imdb_data['country'] == k)]['gross'].mean()
        imdb_data.loc[(imdb_data['gross'].isnull()==True)&(imdb_data['director_name'] == i)&(imdb_data['language'] == j)&(imdb_data['country'] == k)]['gross']
    else:
        print('empty')
# Out:
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# ...

# %%
for j,k in zip(imdb_data.loc[(imdb_data['gross'].isnull()==True)]['language'],imdb_data.loc[(imdb_data['gross'].isnull()==True)]['country']):
    if len(imdb_data.loc[(imdb_data['language'] == j)&(imdb_data['country'] == k)]['gross'].value_counts())!=0:
        mean=imdb_data.loc[(imdb_data['language'] == j)&(imdb_data['country'] == k)]['gross'].mean()
        imdb_data.loc[(imdb_data['gross'].isnull()==True)&(imdb_data['language'] == j)&(imdb_data['country'] == k)]['gross']
    else:
        print('empty')
# Out:
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty

# %%
mean=imdb_data['gross'].mean()
imdb_data.loc[imdb_data['gross'].isnull(),'gross']=mean

# %%
for i,j,k in zip(imdb_data.loc[(imdb_data['budget'].isnull()==True)]['director_name'],imdb_data.loc[(imdb_data['budget'].isnull()==True)]['language'],imdb_data.loc[(imdb_data['budget'].isnull()==True)]['country']):
    if len(imdb_data.loc[(imdb_data['director_name'] == i)&(imdb_data['language'] == j)&(imdb_data['country'] == k)]['budget'].value_counts())!=0:
        mean=imdb_data.loc[(imdb_data['director_name'] == i)&(imdb_data['language'] == j)&(imdb_data['country'] == k)]['budget'].mean()
        imdb_data.loc[(imdb_data['budget'].isnull()==True)&(imdb_data['director_name'] == i)&(imdb_data['language'] == j)&(imdb_data['country'] == k)]['budget']
    else:
        print('empty')
# Out:
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# ...

# %%
for j,k in zip(imdb_data.loc[(imdb_data['budget'].isnull()==True)]['language'],imdb_data.loc[(imdb_data['budget'].isnull()==True)]['country']):
    if len(imdb_data.loc[(imdb_data['language'] == j)&(imdb_data['country'] == k)]['budget'].value_counts())!=0:
        mean=imdb_data.loc[(imdb_data['language'] == j)&(imdb_data['country'] == k)]['gross'].mean()
        imdb_data.loc[(imdb_data['budget'].isnull()==True)&(imdb_data['language'] == j)&(imdb_data['country'] == k)]['budget']
    else:
        print('empty')
# Out:
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty

# %%
mean=imdb_data['budget'].mean()
mean
imdb_data.loc[imdb_data['budget'].isnull(),'budget']=mean

# %%
imdb_data.isnull().sum()
# Out:
# director_name            0
# duration                12
# actor_1_name             0
# num_voted_users          0
# gross                    0
# genres                   0
# movie_title              0
# language                 0
# country                  0
# budget                   0
# title_year               2
# imdb_score               0
# movie_facebook_likes     0
# dtype: int64

# %%
mean=imdb_data['title_year'].median()
mean
imdb_data.loc[imdb_data['title_year'].isnull(),'title_year']=mean

# %%
mean=imdb_data['duration'].mean()
mean
imdb_data.loc[imdb_data['duration'].isnull(),'duration']=mean

# %%
imdb_data['genres'] = imdb_data['genres'].str.split('|')
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_16432\2941620849.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_data['genres'] = imdb_data['genres'].str.split('|')

# %%
imdb_data=imdb_data.explode('genres')

# %%
imdb_data.to_excel('imdb_excel.xlsx',index=False)
